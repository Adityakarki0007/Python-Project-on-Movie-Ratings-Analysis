# %%
import pandas as pd

# %%
movie = pd.read_csv("C:\\Users\\ADI\\Downloads\\Python CSV\\R-Programming-A-Z-master\\Movie-Ratings.csv")

# %%
movie.columns = ['Film','Genre','CriticRating','AudienceRating','BudgetMillions','Year'] #changed_name_of_Headers

# %%
movie
# Out:
#                            Film      Genre  CriticRating  AudienceRating  \
# 0         (500) Days of Summer      Comedy            87              81
# 1                   10,000 B.C.  Adventure             9              44
# 2                    12 Rounds      Action            30              52
# 3                     127 Hours  Adventure            93              84
# 4                     17 Again      Comedy            55              70
# ..                          ...        ...           ...             ...
# 557             Youth in Revolt     Comedy            68              52
# 558  Zack and Miri Make a Porno    Romance            64              70
# 559                      Zodiac   Thriller            89              73
# 560                 Zombieland      Action            90              87
# 561                   Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
k1 = sns.kdeplot(data=movie, x="BudgetMillions" , y="AudienceRating" , shade=True,shade_lowest=False,cmap='Blues')

# %%
k2 = sns.kdeplot(data=movie, x="BudgetMillions" , y="CriticRating" , shade=True,shade_lowest=False,cmap='Oranges')

# %%
k3 = sns.kdeplot(data=movie, x="CriticRating" , y="AudienceRating" , shade=True,shade_lowest=False,cmap='Reds')

# %%
k4= sns.violinplot(data=movie, x='Genre' , y='CriticRating')

# %%
p = plt.hist(movie[movie.Genre=='Action'].BudgetMillions)

# %%
#Subplot of 4 charts 

sns.set_style('whitegrid')
f, axes = plt.subplots(2,2,figsize=(15,15))
k1 = sns.kdeplot(data=movie, x="CriticRating" , y="AudienceRating" , shade=True,shade_lowest=False,cmap='Reds', ax=axes[0,0])
k2 = sns.kdeplot(data=movie, x="BudgetMillions" , y="CriticRating" , shade=True,shade_lowest=False,cmap='Oranges',ax=axes[1,0])
k3 = sns.kdeplot(data=movie, x="CriticRating" , y="AudienceRating" , shade=True,shade_lowest=False,cmap='Reds',ax=axes[0,1])
k4 = sns.violinplot(data=movie, x='Genre' , y='CriticRating',ax=axes[1,1])

#if_the_fuction_is_(plt)_then_do_this_--> axes[1,1].hist(movie.BudgetMillions)_

# %%
#Subplot of 4 charts ( advance styling ) 

sns.set_style('darkgrid', {'axes.facecolor' :'Black'})
f, axes = plt.subplots(2,2,figsize=(15,15))

k1 = sns.kdeplot(data=movie, x="CriticRating" , y="AudienceRating" , shade=True,shade_lowest=False,cmap='inferno', ax=axes[0,0])
k1b = sns.kdeplot(data=movie, x="CriticRating" , y="AudienceRating" , cmap='cool', ax=axes[0,0])

k2 = sns.kdeplot(data=movie, x="BudgetMillions" , y="CriticRating" , shade=True,shade_lowest=False,cmap='turbo',ax=axes[1,0])
k2b = sns.kdeplot(data=movie, x="BudgetMillions" , y="CriticRating" ,cmap='Set3',ax=axes[1,0])

k3 = sns.kdeplot(data=movie, x="CriticRating" , y="AudienceRating" , shade=True,shade_lowest=False,cmap= 'gist_gray_r',ax=axes[0,1])
k3b = sns.kdeplot(data=movie, x="CriticRating" , y="AudienceRating" ,cmap='Set3',ax=axes[0,1])

k4 = sns.violinplot(data=movie, x='Genre' , y='CriticRating',ax=axes[1,1]  )
